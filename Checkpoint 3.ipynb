# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("titanic-passengers.csv", sep=";")

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0          343       No       2
# 1           76       No       3
# 2          641       No       3
# 3          568       No       3
# 4          672       No       1
# 5          105       No       3
# 6          576       No       3
# 7          382      Yes       3
# 8          228       No       3
# 9          433      Yes       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived        object
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(), inplace= True)

# %%
df.head(100)
# Out:
#     PassengerId Survived  Pclass  \
# 0           343       No       2
# 1            76       No       3
# 2           641       No       3
# 3           568       No       3
# 4           672       No       1
# ..          ...      ...     ...
# 95          525       No       3
# 96          131       No       3
# 97          889       No       3
# 98           32      Yes       1
# 99           96       No       3
#
#                                               Name     Sex        Age  SibSp  \
# 0                       Collander, Mr. Erik Gustaf    male  28.000000      0
# 1                          Moen, Mr. Sigurd Hansen    male  25.000000      0
# 2                           Jensen, Mr. Hans Peder    male  20.000000      0
# 3      Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000      0
# 4                           Davidson, Mr. Thornton    male  31.000000      1
# ..                                             ...     ...        ...    ...
# ...

# %%
df= df.drop(columns=['Ticket', 'PassengerId', 'Cabin'])

# %%
df
# Out:
#     Survived  Pclass                                               Name  \
# 0         No       2                         Collander, Mr. Erik Gustaf
# 1         No       3                            Moen, Mr. Sigurd Hansen
# 2         No       3                             Jensen, Mr. Hans Peder
# 3         No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         No       1                             Davidson, Mr. Thornton
# ..       ...     ...                                                ...
# 886      Yes       2                Nasser, Mrs. Nicholas (Adele Achem)
# 887       No       3                              Sirayanian, Mr. Orsen
# 888       No       3                                Cacic, Miss. Marija
# 889       No       3                   Petroff, Mr. Pastcho ("Pentcho")
# 890      Yes       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...
#
#         Sex        Age  SibSp  Parch     Fare Embarked
# ...

# %%
df['Title'] = df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
df = df.drop(columns='Name')

# %%
df
# Out:
#     Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked Title
# 0         No       2    male  28.000000      0      0  13.0000        S    Mr
# 1         No       3    male  25.000000      0      0   7.6500        S    Mr
# 2         No       3    male  20.000000      0      0   7.8542        S    Mr
# 3         No       3  female  29.000000      0      4  21.0750        S   Mrs
# 4         No       1    male  31.000000      1      0  52.0000        S    Mr
# ..       ...     ...     ...        ...    ...    ...      ...      ...   ...
# 886      Yes       2  female  14.000000      1      0  30.0708        C   Mrs
# 887       No       3    male  22.000000      0      0   7.2292        C    Mr
# 888       No       3  female  30.000000      0      0   8.6625        S  Miss
# 889       No       3    male  29.699118      0      0   7.8958        S    Mr
# 890      Yes       2  female  19.000000      0      0  26.0000        S  Miss
#
# [891 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# Title       0
# dtype: int64

# %%
print(df["Embarked"].value_counts())
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Embarked"].fillna('S', inplace = True)

# %%
df.head()
# Out:
#   Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Title
# 0       No       2    male  28.0      0      0  13.0000        S    Mr
# 1       No       3    male  25.0      0      0   7.6500        S    Mr
# 2       No       3    male  20.0      0      0   7.8542        S    Mr
# 3       No       3  female  29.0      0      4  21.0750        S   Mrs
# 4       No       1    male  31.0      1      0  52.0000        S    Mr

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# Title       0
# dtype: int64

# %%
# 2. Visualization phase:

# %%
df.Survived.value_counts()
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
plt = df.Survived.value_counts().plot( kind ='bar', rot = 0, color = ['y', 'tan'])
plt.set_xlabel('Survived or not')
plt.set_ylabel('Passenger Count')
plt
# Out:
# <AxesSubplot:xlabel='Survived or not', ylabel='Passenger Count'>

# %%
plt = df.Sex.value_counts().sort_index().plot(kind='bar',color=['m','c'], rot = 45)
plt.set_xlabel('Sex')
plt.set_ylabel('Passenger count')
# Out:
# Text(0, 0.5, 'Passenger count')

# %%
sns.countplot(x='Survived',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
# From this plot, we can see clearly that there were a higher number of female survivors on the Titanic than male.

# %%
sns.countplot(x='Survived',hue='Pclass',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Embarked',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
df
# Out:
#     Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked Title
# 0         No       2    male  28.000000      0      0  13.0000        S    Mr
# 1         No       3    male  25.000000      0      0   7.6500        S    Mr
# 2         No       3    male  20.000000      0      0   7.8542        S    Mr
# 3         No       3  female  29.000000      0      4  21.0750        S   Mrs
# 4         No       1    male  31.000000      1      0  52.0000        S    Mr
# ..       ...     ...     ...        ...    ...    ...      ...      ...   ...
# 886      Yes       2  female  14.000000      1      0  30.0708        C   Mrs
# 887       No       3    male  22.000000      0      0   7.2292        C    Mr
# 888       No       3  female  30.000000      0      0   8.6625        S  Miss
# 889       No       3    male  29.699118      0      0   7.8958        S    Mr
# 890      Yes       2  female  19.000000      0      0  26.0000        S  Miss
#
# [891 rows x 9 columns]

# %%
df.Title.value_counts().plot(kind='bar',color=['c','orange','m','y','purple','turquoise','navy'])
# Out:
# <AxesSubplot:>

# %%
df['Title'] = df['Title'].replace(['Dr', 'Rev', 'Col', 'Major', 'Countess', 'Sir', 'Jonkheer', 'Lady', 'Capt', 'Don'], 'Others')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')
df['Title'] = df['Title'].replace('Mlle', 'Miss')

# %%
plt = df.SibSp.value_counts().sort_index().plot(kind='bar',color=['lightpink','skyblue','green','purple','lightgreen','pink'])
plt.set_xlabel('SibSp')
plt.set_ylabel('Passenger count')
# Out:
# Text(0, 0.5, 'Passenger count')

# %%
df.head()
# Out:
#   Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Title
# 0       No       2    male  28.0      0      0  13.0000        S    Mr
# 1       No       3    male  25.0      0      0   7.6500        S    Mr
# 2       No       3    male  20.0      0      0   7.8542        S    Mr
# 3       No       3  female  29.0      0      4  21.0750        S   Mrs
# 4       No       1    male  31.0      1      0  52.0000        S    Mr

# %%
df['Survived'] = df['Survived'].map({'No':0, 'Yes':1})

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Title
# 0         0       2    male  28.0      0      0  13.0000        S    Mr
# 1         0       3    male  25.0      0      0   7.6500        S    Mr
# 2         0       3    male  20.0      0      0   7.8542        S    Mr
# 3         0       3  female  29.0      0      4  21.0750        S   Mrs
# 4         0       1    male  31.0      1      0  52.0000        S    Mr

# %%
plt = df[['SibSp', 'Survived']].groupby('SibSp').mean().Survived.plot(kind='bar')
plt.set_xlabel('SibSp')
plt.set_ylabel('Survival Probability')
# Out:
# Text(0, 0.5, 'Survival Probability')

# %%
df['Sex'] = df['Sex'].map({'male':0, 'female':1})
df['Embarked'] = df['Embarked'].map({'C':0, 'Q':1, 'S':2})

# %%
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked Title
# 0           0       2    0  28.000000      0      0  13.0000         2    Mr
# 1           0       3    0  25.000000      0      0   7.6500         2    Mr
# 2           0       3    0  20.000000      0      0   7.8542         2    Mr
# 3           0       3    1  29.000000      0      4  21.0750         2   Mrs
# 4           0       1    0  31.000000      1      0  52.0000         2    Mr
# ..        ...     ...  ...        ...    ...    ...      ...       ...   ...
# 886         1       2    1  14.000000      1      0  30.0708         0   Mrs
# 887         0       3    0  22.000000      0      0   7.2292         0    Mr
# 888         0       3    1  30.000000      0      0   8.6625         2  Miss
# 889         0       3    0  29.699118      0      0   7.8958         2    Mr
# 890         1       2    1  19.000000      0      0  26.0000         2  Miss
#
# [891 rows x 9 columns]

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked Title  \
# 0         0       2    0  28.0      0      0  13.0000         2    Mr
# 1         0       3    0  25.0      0      0   7.6500         2    Mr
# 2         0       3    0  20.0      0      0   7.8542         2    Mr
# 3         0       3    1  29.0      0      4  21.0750         2   Mrs
# 4         0       1    0  31.0      1      0  52.0000         2    Mr
#
#    FamilySize
# 0           1
# 1           1
# 2           1
# 3           5
# 4           2
